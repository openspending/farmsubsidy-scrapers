# %%
import base64
from collections import OrderedDict
import time
import json
import os
import string

import requests
from lxml import html

from IPython.core.display import display, HTML
from IPython.display import clear_output

from tqdm import tqdm_notebook

import pandas as pd

from slugify import slugify

from captcha.agea_captcha import captcha
# Out:
# /home/sw/notebooks/notebook35/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
cs = captcha.CaptchaSolver(model_path='captcha/agea_11.h5')

# %%
YEAR = 2017

# %%
START_URL = 'https://www.sian.it/pubbAimu/start.do'
START2_URL = 'https://www.sian.it/pubbAimu/beneficiari/start.do'
YEAR_SELECTION = 'https://www.sian.it/pubbAimu/beneficiari/ricerca/switch.do'
CAPTCHA_URL = 'https://www.sian.it/pubbAimu/Captcha.jpg'
SEARCH_URL = 'https://www.sian.it/pubbAimu/beneficiari/ricerca/switch.do'
BAD_CAPTCHA = "I caratteri digitati non corrispondono a quelli presenti"
SESSION_ERROR = 'ERRORE DI SISTEMA'
NO_RECIPIENTS = 'beneficiario trovato per i criteri'
TOKEN_NAME = 'org.apache.struts.taglib.html.TOKEN'

# %%
def to_curl(response):
    req = response.request

    command = "curl -X {method} -H {headers} -d '{data}' '{uri}'"
    method = req.method
    uri = req.url
    data = req.body
    headers = ['"{0}: {1}"'.format(k, v) for k, v in req.headers.items()]
    headers = " -H ".join(headers)
    return command.format(method=method, headers=headers, data=data, uri=uri)

def extract_select(options):
    for macro in options:
        key = macro.attrib['value']
        label = macro.text_content()
        yield key, label

def get_session():
    session = requests.Session()
    session.get(START_URL)
    response = session.get(START2_URL)
    
    root = html.fromstring(response.text)
    amounts = root.xpath('//select[@name="ricercaImportoPagamenti"]/option/@value')

    macro_measure = dict(extract_select(root.xpath('//select[@name="ricercaMacroMisura"]/option')[1:]))
    return session, {'amounts': amounts[1:], 'measures': macro_measure}

# %%
def collect_measure(session, year, macro):
    post_data = {
        'ricercaEsercizioFinanziario': str(year),
        'ricercaDenominazione': '',
        'ricercaComuneResidenza': '',
        'ricercaImportoPagamenti': '',
        'ricercaMacroMisura': str(macro),
        'caratteriImmagine': '',
        'desiredTarget': '',
    }
    response = session.post(SEARCH_URL, data=post_data, allow_redirects=False, headers={
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
        'Content-Type': 'application/x-www-form-urlencoded',
        'Referer': 'https://www.sian.it/pubbAimu/beneficiari/elenco/load.do',
        'Host': 'www.sian.it',
        'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/64.0.3282.186 Safari/537.36'
    })
    root = html.fromstring(response.text)
    return dict(extract_select(root.xpath('//select[@name="ricercaMisura"]/option')[1:]))
        
def collect_measures(year):
    session, params = get_session()
    for m in tqdm_notebook(params['measures']):
        yield m, collect_measure(session, year, m)

# %%
MEASURES = {
    YEAR: dict(collect_measures(YEAR))
}
MEASURES
# Out:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
# {2017: {'1': {'1': 'Regime di pagamento unico (RPU)',
#    '102': 'Altro (aiuti diretti disaccoppiati)',
#    '103': 'Premi per le vacche nutrici',
#    '104': 'Premio supplementare per vacca nutrice',
#    '105': 'Premio per ovini e caprini',
#    '106': 'Premio supplementare per ovini e caprini',
#    '107': 'Aiuto per i bachi da seta',
#    '108': 'Pagamenti per specifici tipi di colture e di produzione di qualità',
#    '109': 'Supplemento per i coltivatori di barbabietole da zucchero e canna da zucchero',
#    '111': 'Pagamento transitorio per i prodotti ortofrutticoli - Prodotti diversi dai pomodori',
#    '112': 'Sostegno specifico (articolo 68) - Aiuti diretti accoppiati',
#    '115': 'Altro (aiuti diretti)',
#    '116': 'Aiuti aggiuntivi',
#    '2': 'Regime di pagamento unico per superficie (RPUS)',
#    '238': 'Rimborso degli aiuti diretti con i meccanismi di disciplina finanziaria',
#    '3': 'Pagamento distinto per lo zucchero',
#    '4': 'Pagamento separato per i prodotti ortofrutticoli',
#    '5': 'Sostegno specifico (articolo 68) - Aiuti diretti disaccoppiati',
#    '6': 'Pagamento distinto per i frutti rossi'},
#   '2': {'110': 'Aiuto per superficie per il cotone',
#    '113': 'POSEI - Programmi di sostegno dell-Unione europea',
#    '114': 'POSEI - Isole dell Egeo',
#    '233': 'Regime di pagamento di base',
#    '234': " Pagamento a favore delle pratiche agricole benefiche per il clima e l'ambiente",
#    '235': 'Pagamento per i giovani agricoltori',
#    '236': 'Regime di sostegno accoppiato facoltativo',
#    '237': 'Regime per i piccoli agricoltori',
#    '7': 'Pagamenti redistributivi'},
#   '3': {'117': 'Restituzioni all esportazione per i cereali',
#    '118': 'Interventi all ammasso di cereali',
#    '119': 'Altre misure (cereali)',
#    '120': 'Restituzioni all esportazione per il riso',
#    '121': 'Interventi all ammasso di riso',
#    '122': 'Altre misure (riso)',
#    '123': 'Restituzioni per i prodotti fuori allegato 1',
#    '124': 'Altre misure (programmi alimentari)',
#    '125': 'Restituzioni all esportazione per lo zucchero e l isoglucosio',
#    '126': 'Restituzioni alla produzione per l utilizzazione nell industria chimica',
#    '127': 'Misure di ammasso per lo zucchero',
#    '128': 'Altre misure (zucchero)',
#    '129': 'Interventi all ammasso per l olio d oliva',
#    '130': 'Miglioramento della qualità dei prodotti',
#    '131': 'Altre misure (olio di oliva)',
#    '132': 'Misure di ammasso per le fibre di lino',
#    '133': 'Cotone - Programmi nazionali di ristrutturazione',
#    '134': 'Altre misure (piante tessili)',
#    '135': 'Fondo operativo delle organizzazioni di produttori',
#    '136': 'Aiuti ai gruppi di produttori prericonosciuti',
#    '137': 'Programma Frutta nelle scuole',
#    '138': 'Altre misure (prodotti ortofrutticoli)',
#    '139': 'Programmi nazionali di sostegno al settore vitivinicolo',
#    '140': 'Altre misure (settore vitivinicolo)',
#    '141': 'Luppolo - Aiuto alle organizzazioni di produttori',
#    '142': 'POSEI (esclusi gli aiuti diretti)',
#    '143': 'Altre misure (altri prodotti vegetali/misure)',
#    '144': 'Restituzioni per i prodotti lattiero-caseari',
#    '145': 'Interventi all ammasso di latte scremato in polvere',
#    '146': 'Aiuto allo smercio di latte scremato',
#    '147': 'Interventi all ammasso del burro e della crema',
#    '148': 'Latte alle scuole',
#    '149': 'Altre misure (latte e prodotti lattiero-caseari)',
#    '150': 'Restituzioni per le carni bovine',
#    '151': 'Interventi all ammasso di carni bovine',
#    '152': 'Restituzioni per gli animali vivi',
#    '153': 'Altre misure (carni bovine)',
#    '154': 'Interventi all ammasso di carni ovine e caprine',
#    '155': 'Altre misure (carni ovine e caprine)',
#    '156': 'Restituzioni per le carni suine',
#    '157': 'Interventi all ammasso di carni suine',
#    '158': 'Restituzioni per le uova',
#    '159': 'Restituzioni per il pollame',
#    '160': 'Aiuto particolare all apicoltura',
#    '161': 'Altre misure (carni suine, pollame, uova, apicoltura e altri prodotti animali)'},
#   '4': {'210': 'Investimenti in immobilizzazioni materiali',
#    '211': "Investimenti nello sviluppo delle aree forestali e nel miglioramento della redditivita' delle foreste",
#    '212': "Indennita' a favore delle zone soggette a vincoli naturali o ad altri vincoli specifici",
#    '213': 'Prepensionamento',
#    '214': 'Trasferimento di conoscenze e azioni di informazione',
#    '215': 'Servizi di consulenza, di sostituzione e di assistenza alla gestione delle aziende agricole',
#    '216': 'Regimi di qualità dei prodotti agricoli e alimentari',
#    '217': 'Ripristino del potenziale produttico agricolo danneggiato da calamità naturali e da eventi catastrofici e introduzione di adeguate misure di prevenzione',
#    '218': 'Sviluppo delle aziende agricole e delle imprese',
#    '219': 'Servizi di base e rinnovamento dei villaggi nelle zone rurali',
#    '220': 'Costituzione di associazioni e organizzazione di produttori',
#    '221': 'Pagamenti agro-climatico-ambientali',
#    '222': 'Agricoltura biologica',
#    '223': "Indennità Natura 2000 e indennità connesse alla direttiva quadro sull'acqua",
#    '224': 'Benessere degli animali',
#    '225': 'Servizi silvo-ambientali e climatici salvaguardia delle foreste',
#    '226': 'Cooperazione',
#    '227': 'Gestione del rischio',
#    '228': 'Finanziamento dei pagamenti diretti nazionali integrativi in Croazia',
#    '229': 'Sostegno ai gruppi di azione locale Leader (CLLD-sviluppo locale di tipo partecipativo)',
#    '230': 'Assistenza tecnica',
#    '231': "Rispetto dei requisiti prescritti dalla normativa dell'unione",
#    '232': 'Animazione, acquisizione di competenze e attuazione di strategie di sviluppo locale'},
#   '5': {'162': 'Azioni nel campo della formazione professionale e dell informazione',
#    '163': 'Insediamento di giovani agricoltori-',
#    '164': 'Prepensionamento',
#    '165': 'Ricorso a servizi di consulenza',
#    '166': 'Avviamento di servizi di consulenza aziendale, di sostituzione e di assistenza alla gestione',
#    '167': 'Ammodernamento delle aziende agricole',
#    '168': 'Accrescimento del valore economico delle foreste',
#    '169': 'Accrescimento del valore aggiunto dei prodotti agricoli e forestali',
#    '170': 'Promozione dello sviluppo di nuovi prodotti, processi e tecnologie nel settore agricolo e alimentare e in quello forestale',
#    '171': 'Infrastruttura connessa allo sviluppo e all adeguamento dell agricoltura e della silvicoltura -',
#    '172': 'Ripristino del potenziale produttivo agricolo danneggiato da calamità naturali e introduzione di adeguate misure di prevenzione',
#    '173': 'Rispetto dei requisiti prescritti dalla normativa comunitaria',
#    '174': 'Partecipazione degli agricoltori ai sistemi di qualità alimentare',
#    '175': 'Attività di informazione e promozione',
#    '176': 'Agricoltura di semisussistenza',
#    '177': 'Associazioni di produttori',
#    '178': 'Prestazione di servizi di consulenza e di divulgazione agricole in Bulgaria e in Romania',
#    '179': 'Aziende in via di ristrutturazione a seguito di una riforma dell organizzazione comune di mercato',
#    '180': 'Indennità compensative degli svantaggi naturali a favore degli agricoltori delle zone montane',
#    '181': 'Indennità a favore degli agricoltori delle zone caratterizzate da svantaggi naturali diverse dalle zone montane',
#    '182': 'Indennità Natura 2000 e indennità connesse alla direttiva 2000/60/CE',
#    '183': 'Pagamenti agroambientali',
#    '184': 'Pagamenti per il benessere degli animali',
#    '185': 'Investimenti non produttivi',
#    '186': 'Primo imboschimento di terreni agricoli',
#    '187': 'Primo impianto di sistemi agroforestali su terreni agricoli',
#    '188': 'Primo imboschimento di terreni non agricoli',
#    '189': 'Indennità Natura 2000 - Fondi addizionali di cui all articolo 69, paragrafo 5 bis, del regolamento (CE) n. 698/2005 del Consiglio',
#    '190': 'Pagamenti silvo-ambientali',
#    '191': 'Ricostituzione del potenziale produttivo forestale e interventi preventivi',
#    '192': 'Investimenti non produttivi',
#    '193': 'Diversificazione verso attività non agricole',
#    '194': 'Creazione e sviluppo di imprese',
#    '195': 'Incentivazione di attività turistiche',
#    '196': 'Servizi essenziali per l economia e la popolazione rurale',
#    '197': 'Sviluppo e rinnovamento dei villaggi',
#    '198': 'Tutela e riqualificazione del patrimonio rurale',
#    '199': 'Formazione e informazione',
#    '200': 'Animazione, acquisizione di competenze e attuazione di strategie di sviluppo locale',
#    '201': 'Attuazione di strategie di sviluppo locale -Competitività -',
#    '202': 'Attuazione di strategie di sviluppo locale - Ambiente/gestione del territorio',
#    '203': 'Attuazione di strategie di sviluppo locale - Qualità di vita/diversificazione',
#    '204': 'Progetti di cooperazione',
#    '205': 'Gestione dei gruppi di azione locale, acquisizione di competenze e animazione sul territorio (articolo 59)',
#    '206': 'Assistenza tecnica',
#    '207': 'Pagamenti diretti complementari'},
#   '6': {},
#   '7': {'208': 'Azioni di promozione - Pagamenti da parte degli Stati membri',
#    '209': 'Altre misure (promozione)'},
#   '8': {},
#   '9': {}}}

# %%
class SessionError(Exception):
    pass


class TooManyError(Exception):
    def __init__(self, query):
        self.query = query


def has_persistent(key, filename='already.json'):
    if os.path.exists(filename):
        with open(filename) as f:
            data = json.load(f)
        return key in data
    else:
        return False

    
def has_failed(key):
    return has_persistent(key, filename='failed.json')

    
def add_failed(query, data=None):
    add_persistent(query, data=data, filename='failed.json')

def add_persistent(key, data=None, filename='already.json'):
    if data is None:
        if os.path.exists(filename):
            with open(filename) as f:
                data = json.load(f)
        else:
            data = {}
    data[key] = True
    with open(filename, 'w') as f:
        json.dump(data, f)


def get_sub_queries(query):
    if len(query) == 3:
        yield from get_macro_sub_queries(query)
    elif len(query) == 4:
        yield from get_name_sub_queries(query)
        
        
def get_name_sub_queries(query):
    letters = string.ascii_uppercase
    for l1 in letters:
        for l2 in letters:
            q = OrderedDict(query)
            q.update({
                'ricercaDenominazione': l1 + l2
            })
            yield q
        
    
def get_macro_sub_queries(query):
    year, macro = query['ricercaEsercizioFinanziario'], query['ricercaMacroMisura']
    for micro in MEASURES[year][macro]:
        q = OrderedDict(query)
        q.update({
            'ricercaMisura': micro
        })
        yield q

def get_queries(params, year):
    for amount in reversed(params['amounts']):
        for macro in params['measures']:
            yield OrderedDict([
                ('ricercaImportoPagamenti', amount),
                ('ricercaMacroMisura', macro),
                ('ricercaEsercizioFinanziario', year),
            ])

def start_search(year):
    session, params = get_session()
    queries = get_queries(params, year)
    for result_list in start_queries(queries):
        if result_list is not None:
            yield result_list

        
def start_queries(queries):
    for query in queries:
        yield from start_query(query)

def start_query(query):
    key = str(query)
    if has_failed(key):
        yield from run_subqueries(query)
        return
    try:
        result_list = run_with_query(query)
        yield result_list
    except TooManyError as e:
        add_failed(key)
        yield from run_subqueries(query)

def run_subqueries(query):
    for subquery in get_sub_queries(query):
        yield from start_query(subquery)
        

def run_with_query(query):
    key = str(query)
    if has_persistent(key):
        return None

    session, _ = get_session()
    count = 0
    while True:
        try:
            print('Searching', query)
            result_list = perform_search(session, query, count=count)
            add_persistent(key)
            return result_list
        except SessionError:
            count += 1
            print('Session Error!', count)
            session, _ = get_session()
                
                
def get_detail(session, token, query, idList):
    print('Getting detail for', idList, 'sleeping...')
    time.sleep(5)
    print('Getting detail for', idList)
    post_data = OrderedDict([
        ('org.apache.struts.taglib.html.TOKEN', token,),
        ('ricercaDenominazione', '',),
        ('ricercaComuneResidenza', '',),
        ('ricercaImportoPagamenti', '1',),
        ('ricercaEsercizioFinanziario', str(YEAR),),
        ('ricercaMacroMisura', '1',),
        ('ricercaMisura', '',),
        ('idLista', idList,),
        ('desiredTarget', 'Detail',),
    ])
    post_data.update(query)
    response = session.post(SEARCH_URL, data=post_data, headers={
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
        'Content-Type': 'application/x-www-form-urlencoded',
        'Referer': 'https://www.sian.it/pubbAimu/beneficiari/elenco/load.do',
        'Host': 'www.sian.it',
        'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/64.0.3282.186 Safari/537.36'
    })
    print(to_curl(response))
    # %debug
    root = html.fromstring(response.text)
    table = root.xpath('//table[contains(@class, "regpub_dati")]/following-sibling::table')[0]
    trs = table.xpath('.//tr[position() > 1]')
    for tr in trs:
        tds = tr.xpath('./td')
        measure_1 = tds[0].text_content().replace(' - ', '')
        measure_2 = tds[1].text_content().replace(' - ', '')
        amount = float(tds[2].text_content().replace('.', '').replace(',', '.'))
        yield {
            'scheme': '%s - %s' % (measure_1, measure_2),
            'amount': amount,
            'currency': 'EUR',
            'year': YEAR
        }


def extract_recipients(session, token, query, table):
    trs = table.xpath('.//tr[position() > 1]')
    num_results = len(trs)
    for num, tr in enumerate(trs):
        print('%.2f%%\r' % (num / num_results * 100), end='')
        tds = tr.xpath('./td')
        amount = float(tds[4].text_content().replace('.', '').replace(',', '.'))
        idList = tds[5].xpath('./input/@value')[0]
        recipient_name = tds[0].text_content()
        recipient_location = '%s, %s' % (tds[1].text_content(), tds[3].text_content())
        recipient_postcode = tds[2].text_content()
        base = {
            'recipient_name': recipient_name,
            'recipient_location': recipient_location,
            'recipient_postcode': recipient_postcode,
            'total_amount': amount,
            'country': 'IT',
        }
        base['recipient_id'] = '%s-%s-%s' % (slugify(recipient_name),
                                             recipient_postcode,
                                             slugify(recipient_location))
        yield base
#         subsidies = get_detail(session, token, query, idList)
#         for sub in subsidies:
#             d = dict(base)
#             d.update(sub)
#             yield d
    
    
def enter_captcha(session):
    response = session.get(CAPTCHA_URL)
    uri = ("data:" + 
           response.headers['Content-Type'] + ";" +
           "base64," + base64.b64encode(response.content).decode('utf-8'))
    display(HTML('<img src="{}">'.format(uri)))
    return input('Captcha: '), uri

def solve_captcha(session):
    response = session.get(CAPTCHA_URL)
    solution = cs.predict_from_bytes(response.content)
    uri = ("data:" + 
           response.headers['Content-Type'] + ";" +
           "base64," + base64.b64encode(response.content).decode('utf-8'))
#     display(HTML('<img src="{}">'.format(uri)))
#     print('Auto-Captcha:', solution)
    return solution, uri

def store_captcha(solution, uri):
    with open('captchas.txt', 'a') as f:
        f.write('%s|%s\n' % (solution, uri))
    
def perform_search(session, query, count=0):
    minor_measures = None
    while True:
#         print('Trying captcha for', query)
        solution, uri = solve_captcha(session)

        year_post = {
            'ricercaEsercizioFinanziario': str(YEAR),
            'ricercaDenominazione':'',
            'ricercaComuneResidenza':'',
            'ricercaImportoPagamenti': '1',
            'ricercaMacroMisura': '1',
            'caratteriImmagine': solution,
            'desiredTarget':'Find',
        }
        year_post.update(query)
        try:
            response = session.post(SEARCH_URL, data=year_post, headers={
                'Content-Type': 'application/x-www-form-urlencoded',
                'Referer': 'https://www.sian.it/pubbAimu/beneficiari/ricerca/switch.do',
            })
        except requests.exceptions.RequestException as e:
            # connection error
            raise TooManyError(query)

        if not response.text:
            raise SessionError

        if BAD_CAPTCHA in response.text:
            print('Bad captcha!')
            continue

        #  Store correctly solved captcha for training data
        store_captcha(solution, uri)

        if NO_RECIPIENTS in response.text:
            return []
        
        if SESSION_ERROR in response.text:
            raise SessionError
        root = html.fromstring(response.text)
        table = root.xpath('//table[@id="results"]')
        if not table:
            print('no table')
            display(HTML(response.text))
            if count > 1:
                break
            raise SessionError
        token = root.xpath('.//input[@name="%s"]/@value' % TOKEN_NAME)[0]
        return list(extract_recipients(session, token, query, table[0]))

# %%
filename = 'it_%s_raw.csv.gz' % YEAR
if os.path.exists(filename):
    df = pd.read_csv(filename, compression='gzip', converters={'recipient_postcode': str})
else:
    df = pd.DataFrame()
for data in tqdm_notebook(start_search(YEAR)):
    df = pd.concat([df, pd.DataFrame(data)])
    print(len(df))
    df.to_csv(filename, index=False, compression='gzip')
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Searching OrderedDict([('ricercaImportoPagamenti', '6'), ('ricercaMacroMisura', '7'), ('ricercaEsercizioFinanziario', 2017)])
# Bad captcha!
# Bad captcha!
# Bad captcha!
# 2
# Searching OrderedDict([('ricercaImportoPagamenti', '6'), ('ricercaMacroMisura', '6'), ('ricercaEsercizioFinanziario', 2017)])
# Bad captcha!
# Bad captcha!
# 2
# Searching OrderedDict([('ricercaImportoPagamenti', '6'), ('ricercaMacroMisura', '2'), ('ricercaEsercizioFinanziario', 2017)])
# 4
# Searching OrderedDict([('ricercaImportoPagamenti', '6'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017)])
# Bad captcha!
# 9
# Searching OrderedDict([('ricercaImportoPagamenti', '6'), ('ricercaMacroMisura', '9'), ('ricercaEsercizioFinanziario', 2017)])
# Bad captcha!
# 9
# Searching OrderedDict([('ricercaImportoPagamenti', '6'), ('ricercaMacroMisura', '8'), ('ricercaEsercizioFinanziario', 2017)])
# 9
# Searching OrderedDict([('ricercaImportoPagamenti', '6'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017)])
# 9
# Searching OrderedDict([('ricercaImportoPagamenti', '6'), ('ricercaMacroMisura', '1'), ('ricercaEsercizioFinanziario', 2017)])
# 11
# Searching OrderedDict([('ricercaImportoPagamenti', '6'), ('ricercaMacroMisura', '3'), ('ricercaEsercizioFinanziario', 2017)])
# 40
# Searching OrderedDict([('ricercaImportoPagamenti', '5'), ('ricercaMacroMisura', '7'), ('ricercaEsercizioFinanziario', 2017)])
# Bad captcha!
# 41
# Searching OrderedDict([('ricercaImportoPagamenti', '5'), ('ricercaMacroMisura', '6'), ('ricercaEsercizioFinanziario', 2017)])
# Bad captcha!
# Bad captcha!
# 41
# Searching OrderedDict([('ricercaImportoPagamenti', '5'), ('ricercaMacroMisura', '2'), ('ricercaEsercizioFinanziario', 2017)])
# 72
# Searching OrderedDict([('ricercaImportoPagamenti', '5'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017)])
# 109
# Searching OrderedDict([('ricercaImportoPagamenti', '5'), ('ricercaMacroMisura', '9'), ('ricercaEsercizioFinanziario', 2017)])
# 109
# Searching OrderedDict([('ricercaImportoPagamenti', '5'), ('ricercaMacroMisura', '8'), ('ricercaEsercizioFinanziario', 2017)])
# 109
# Searching OrderedDict([('ricercaImportoPagamenti', '5'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017)])
# 109
# Searching OrderedDict([('ricercaImportoPagamenti', '5'), ('ricercaMacroMisura', '1'), ('ricercaEsercizioFinanziario', 2017)])
# Bad captcha!
# 147
# Searching OrderedDict([('ricercaImportoPagamenti', '5'), ('ricercaMacroMisura', '3'), ('ricercaEsercizioFinanziario', 2017)])
# 209
# Searching OrderedDict([('ricercaImportoPagamenti', '4'), ('ricercaMacroMisura', '7'), ('ricercaEsercizioFinanziario', 2017)])
# 221
# Searching OrderedDict([('ricercaImportoPagamenti', '4'), ('ricercaMacroMisura', '6'), ('ricercaEsercizioFinanziario', 2017)])
# 221
# Searching OrderedDict([('ricercaImportoPagamenti', '4'), ('ricercaMacroMisura', '2'), ('ricercaEsercizioFinanziario', 2017)])
# Bad captcha!
# 4124
# Searching OrderedDict([('ricercaImportoPagamenti', '4'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017)])
# Bad captcha!
# 7503
# Searching OrderedDict([('ricercaImportoPagamenti', '4'), ('ricercaMacroMisura', '9'), ('ricercaEsercizioFinanziario', 2017)])
# Bad captcha!
# 7503
# Searching OrderedDict([('ricercaImportoPagamenti', '4'), ('ricercaMacroMisura', '8'), ('ricercaEsercizioFinanziario', 2017)])
# 7503
# Searching OrderedDict([('ricercaImportoPagamenti', '4'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017)])
# Searching OrderedDict([('ricercaImportoPagamenti', '4'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '191')])
# Bad captcha!
# 7503
# Searching OrderedDict([('ricercaImportoPagamenti', '4'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '192')])
# Bad captcha!
# Bad captcha!
# 7503
# Searching OrderedDict([('ricercaImportoPagamenti', '4'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '200')])
# Bad captcha!
# Bad captcha!
# 7503
# Searching OrderedDict([('ricercaImportoPagamenti', '4'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '163')])
# 7503
# Searching OrderedDict([('ricercaImportoPagamenti', '4'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '166')])
# 7503
# Searching OrderedDict([('ricercaImportoPagamenti', '4'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '179')])
# 7503
# Searching OrderedDict([('ricercaImportoPagamenti', '4'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '173')])
# 7503
# Searching OrderedDict([('ricercaImportoPagamenti', '4'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '165')])
# 7503
# Searching OrderedDict([('ricercaImportoPagamenti', '4'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '167')])
# Bad captcha!
# Bad captcha!
# 7503
# Searching OrderedDict([('ricercaImportoPagamenti', '4'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '196')])
# Bad captcha!
# Bad captcha!
# 7503
# Searching OrderedDict([('ricercaImportoPagamenti', '4'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '164')])
# 7503
# Searching OrderedDict([('ricercaImportoPagamenti', '4'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '202')])
# Bad captcha!
# 7503
# Searching OrderedDict([('ricercaImportoPagamenti', '4'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '193')])
# 7503
# Searching OrderedDict([('ricercaImportoPagamenti', '4'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '183')])
# 7503
# Searching OrderedDict([('ricercaImportoPagamenti', '4'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '201')])
# 7503
# Searching OrderedDict([('ricercaImportoPagamenti', '4'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '203')])
# 7503
# Searching OrderedDict([('ricercaImportoPagamenti', '4'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '199')])
# 7503
# Searching OrderedDict([('ricercaImportoPagamenti', '4'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '170')])
# 7503
# Searching OrderedDict([('ricercaImportoPagamenti', '4'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '162')])
# Bad captcha!
# 7503
# Searching OrderedDict([('ricercaImportoPagamenti', '4'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '207')])
# 7503
# Searching OrderedDict([('ricercaImportoPagamenti', '4'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '174')])
# 7503
# Searching OrderedDict([('ricercaImportoPagamenti', '4'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '189')])
# 7503
# Searching OrderedDict([('ricercaImportoPagamenti', '4'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '190')])
# Bad captcha!
# 7503
# Searching OrderedDict([('ricercaImportoPagamenti', '4'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '181')])
# 7503
# Searching OrderedDict([('ricercaImportoPagamenti', '4'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '169')])
# 7503
# Searching OrderedDict([('ricercaImportoPagamenti', '4'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '175')])
# Bad captcha!
# 7503
# Searching OrderedDict([('ricercaImportoPagamenti', '4'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '178')])
# 7503
# Searching OrderedDict([('ricercaImportoPagamenti', '4'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '185')])
# Bad captcha!
# Bad captcha!
# 7503
# Searching OrderedDict([('ricercaImportoPagamenti', '4'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '205')])
# 7503
# Searching OrderedDict([('ricercaImportoPagamenti', '4'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '198')])
# Bad captcha!
# 7503
# Searching OrderedDict([('ricercaImportoPagamenti', '4'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '171')])
# 7503
# Searching OrderedDict([('ricercaImportoPagamenti', '4'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '194')])
# Bad captcha!
# 7503
# Searching OrderedDict([('ricercaImportoPagamenti', '4'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '186')])
# 7503
# Searching OrderedDict([('ricercaImportoPagamenti', '4'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '188')])
# Bad captcha!
# 7503
# Searching OrderedDict([('ricercaImportoPagamenti', '4'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '176')])
# Bad captcha!
# Bad captcha!
# Bad captcha!
# 7503
# Searching OrderedDict([('ricercaImportoPagamenti', '4'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '172')])
# 7503
# Searching OrderedDict([('ricercaImportoPagamenti', '4'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '197')])
# Bad captcha!
# Bad captcha!
# 7503
# Searching OrderedDict([('ricercaImportoPagamenti', '4'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '184')])
# 7503
# Searching OrderedDict([('ricercaImportoPagamenti', '4'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '204')])
# Bad captcha!
# Bad captcha!
# Bad captcha!
# Bad captcha!
# Bad captcha!
# Bad captcha!
# 7503
# Searching OrderedDict([('ricercaImportoPagamenti', '4'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '206')])
# 7503
# Searching OrderedDict([('ricercaImportoPagamenti', '4'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '187')])
# Bad captcha!
# 7503
# Searching OrderedDict([('ricercaImportoPagamenti', '4'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '168')])
# Bad captcha!
# 7503
# Searching OrderedDict([('ricercaImportoPagamenti', '4'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '195')])
# Bad captcha!
# Bad captcha!
# 7503
# Searching OrderedDict([('ricercaImportoPagamenti', '4'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '182')])
# 7503
# Searching OrderedDict([('ricercaImportoPagamenti', '4'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '177')])
# Bad captcha!
# 7503
# Searching OrderedDict([('ricercaImportoPagamenti', '4'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '180')])
# 7503
# Searching OrderedDict([('ricercaImportoPagamenti', '4'), ('ricercaMacroMisura', '1'), ('ricercaEsercizioFinanziario', 2017)])
# 12786
# Searching OrderedDict([('ricercaImportoPagamenti', '4'), ('ricercaMacroMisura', '3'), ('ricercaEsercizioFinanziario', 2017)])
# Bad captcha!
# 13971
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '7'), ('ricercaEsercizioFinanziario', 2017)])
# 13971
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '6'), ('ricercaEsercizioFinanziario', 2017)])
# 13971
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '2'), ('ricercaEsercizioFinanziario', 2017)])
# Bad captcha!
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '2'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '233')])
# 113971
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '2'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '237')])
# Bad captcha!
# 122817
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '2'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '234')])
# Bad captcha!
# 222817
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '2'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '235')])
# 236568
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '2'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '236')])
# 336568
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '2'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '114')])
# 336568
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '2'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '113')])
# 336568
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '2'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '110')])
# Bad captcha!
# Bad captcha!
# 336568
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '2'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '7')])
# Bad captcha!
# Bad captcha!
# 336568
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017)])
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '210')])
# Bad captcha!
# Bad captcha!
# Bad captcha!
# 336796
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '227')])
# Bad captcha!
# Bad captcha!
# 355258
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '216')])
# Bad captcha!
# 355439
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '232')])
# 355439
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '221')])
# Bad captcha!
# 390870
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '218')])
# Bad captcha!
# Bad captcha!
# 390883
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '217')])
# 390884
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '225')])
# 390892
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '229')])
# Bad captcha!
# 391017
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '219')])
# Bad captcha!
# 391023
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '230')])
# 391024
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '215')])
# Session Error! 1
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '215')])
# 391083
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212')])
# Bad captcha!
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'AA')])
# 391114
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'AB')])
# 394421
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'AC')])
# 398913
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'AD')])
# Bad captcha!
# Bad captcha!
# 401563
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'AE')])
# 402728
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'AF')])
# Bad captcha!
# 403987
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'AG')])
# Bad captcha!
# 413706
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'AH')])
# 413758
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'AI')])
# Bad captcha!
# 415837
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'AJ')])
# 415885
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'AK')])
# 415923
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'AL')])
# Bad captcha!
# 431998
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'AM')])
# 435920
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'AN')])
# 477680
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'AO')])
# Bad captcha!
# Bad captcha!
# Bad captcha!
# Bad captcha!
# Bad captcha!
# 479849
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'AP')])
# 481478
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'AQ')])
# Bad captcha!
# Bad captcha!
# 481550
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'AR')])
# 509208
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'AS')])
# 518243
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'AT')])
# 528661
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'AU')])
# 532695
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'AV')])
# 535171
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'AW')])
# Bad captcha!
# Bad captcha!
# 535175
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'AX')])
# 535221
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'AY')])
# 535286
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'AZ')])
# 539664
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'BA')])
# Bad captcha!
# 544711
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'BB')])
# 545173
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'BC')])
# 545175
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'BD')])
# Session Error! 1
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'BD')])
# 545178
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'BE')])
# 551362
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'BF')])
# 551363
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'BG')])
# 551363
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'BH')])
# 551383
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'BI')])
# Bad captcha!
# Bad captcha!
# 554404
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'BJ')])
# 554404
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'BK')])
# 554421
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'BL')])
# 554602
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'BM')])
# 554605
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'BN')])
# 554626
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'BO')])
# Bad captcha!
# 557401
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'BP')])
# 557401
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'BQ')])
# 557401
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'BR')])
# 560730
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'BS')])
# Bad captcha!
# 560752
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'BT')])
# 560752
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'BU')])
# Bad captcha!
# Bad captcha!
# 561717
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'BV')])
# Bad captcha!
# 561717
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'BW')])
# Bad captcha!
# 561728
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'BX')])
# Bad captcha!
# Bad captcha!
# 561728
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'BY')])
# Bad captcha!
# Bad captcha!
# 561735
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'BZ')])
# Bad captcha!
# Bad captcha!
# 561735
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'CA')])
# 577394
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'CB')])
# Bad captcha!
# Bad captcha!
# Bad captcha!
# Bad captcha!
# 577394
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'CC')])
# 584308
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'CD')])
# Bad captcha!
# 584309
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'CE')])
# 594349
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'CF')])
# 594349
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'CG')])
# 594351
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'CH')])
# Bad captcha!
# 602413
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'CI')])
# Bad captcha!
# 615933
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'CJ')])
# 615933
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'CK')])
# 616049
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'CL')])
# Bad captcha!
# 617032
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'CM')])
# 617032
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'CN')])
# 617082
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'CO')])
# Bad captcha!
# 638537
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'CP')])
# 638538
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'CQ')])
# 638721
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'CR')])
# Bad captcha!
# 639860
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'CS')])
# 639862
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'CT')])
# 639883
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'CU')])
# Bad captcha!
# 641226
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'CV')])
# Bad captcha!
# 641226
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'CW')])
# 641226
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'CX')])
# 641226
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'CY')])
# Bad captcha!
# 641232
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'CZ')])
# Bad captcha!
# 641241
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'DA')])
# 647387
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'DB')])
# 647391
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'DC')])
# 647391
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'DD')])
# Bad captcha!
# Bad captcha!
# 649363
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'DE')])
# 655717
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'DF')])
# 655736
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'DG')])
# Bad captcha!
# 655740
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'DH')])
# 655753
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'DI')])
# Bad captcha!
# 664857
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'DJ')])
# 664858
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'DK')])
# Bad captcha!
# 664858
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'DL')])
# Bad captcha!
# 664919
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'DM')])
# Bad captcha!
# Bad captcha!
# 664962
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'DN')])
# 664981
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'DO')])
# 672233
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'DP')])
# 672234
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'DQ')])
# 672234
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'DR')])
# 675339
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'DS')])
# 675349
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'DT')])
# 675354
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'DU')])
# Bad captcha!
# 676724
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'DV')])
# 676729
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'DW')])
# 676751
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'DX')])
# 676751
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'DY')])
# 676779
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'DZ')])
# 676781
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'EA')])
# 678408
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'EB')])
# Bad captcha!
# 679226
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'EC')])
# 680811
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'ED')])
# 684259
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'EE')])
# 684323
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'EF')])
# 686279
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'EG')])
# 687959
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'EH')])
# 687987
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'EI')])
# Bad captcha!
# 689725
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'EJ')])
# Bad captcha!
# 689740
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'EK')])
# Bad captcha!
# Bad captcha!
# 689752
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'EL')])
# Bad captcha!
# 710081
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'EM')])
# Bad captcha!
# 713637
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'EN')])
# Bad captcha!
# Bad captcha!
# 725468
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'EO')])
# 727664
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'EP')])
# 733208
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'EQ')])
# 733217
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'ER')])
# 754443
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'ES')])
# 763485
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'ET')])
# 776549
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'EU')])
# Bad captcha!
# 776961
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'EV')])
# Bad captcha!
# 777617
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'EW')])
# Bad captcha!
# 777650
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'EX')])
# Bad captcha!
# Bad captcha!
# Bad captcha!
# 777775
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'EY')])
# 777837
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'EZ')])
# 778336
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'FA')])
# 783311
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'FB')])
# Bad captcha!
# 783311
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'FC')])
# 783311
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'FD')])
# 783315
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'FE')])
# 786020
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'FF')])
# 787184
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'FG')])
# Bad captcha!
# Bad captcha!
# 787213
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'FH')])
# Bad captcha!
# Bad captcha!
# Bad captcha!
# 787223
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'FI')])
# Bad captcha!
# 790200
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'FJ')])
# 790201
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'FK')])
# Bad captcha!
# Bad captcha!
# 790201
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'FL')])
# 791043
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'FM')])
# Bad captcha!
# 791083
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'FN')])
# 791112
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'FO')])
# Bad captcha!
# 792861
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'FP')])
# 792861
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'FQ')])
# Bad captcha!
# 792861
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'FR')])
# Bad captcha!
# 799653
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'FS')])
# Bad captcha!
# 799669
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'FT')])
# Bad captcha!
# 799682
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'FU')])
# 800139
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'FV')])
# Bad captcha!
# 800139
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'FW')])
# 800139
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'FX')])
# Bad captcha!
# 800139
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'FY')])
# 800140
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'FZ')])
# 800140
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'GA')])
# 804468
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'GB')])
# 804468
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'GC')])
# Bad captcha!
# Bad captcha!
# 804469
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'GD')])
# Bad captcha!
# 804486
# Searching OrderedDict([('ricercaImportoPagamenti', '3'), ('ricercaMacroMisura', '4'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '212'), ('ricercaDenominazione', 'GE')])
# Bad captcha!
# Bad captcha!
# 810196
# ...
# 2272771
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '9'), ('ricercaEsercizioFinanziario', 2017)])
# 2272771
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '8'), ('ricercaEsercizioFinanziario', 2017)])
# 2272771
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017)])
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '191')])
# Bad captcha!
# 2272771
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '192')])
# 2272771
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '200')])
# 2272771
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '163')])
# 2272771
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '166')])
# 2272771
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '179')])
# 2272771
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '173')])
# Bad captcha!
# Bad captcha!
# 2272771
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '165')])
# Bad captcha!
# 2272771
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '167')])
# Bad captcha!
# Bad captcha!
# 2272771
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '196')])
# Bad captcha!
# 2272771
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '164')])
# 2272771
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '202')])
# 2272771
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '193')])
# Bad captcha!
# 2272771
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '183')])
# 2272771
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '201')])
# Bad captcha!
# Bad captcha!
# Bad captcha!
# 2272771
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '203')])
# 2272771
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '199')])
# 2272771
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '170')])
# 2272771
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '162')])
# Bad captcha!
# Bad captcha!
# Bad captcha!
# Bad captcha!
# 2272771
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '207')])
# Bad captcha!
# 2272771
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '174')])
# Bad captcha!
# 2272771
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '189')])
# Bad captcha!
# 2272771
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '190')])
# Bad captcha!
# 2272771
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '181')])
# 2272771
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '169')])
# Bad captcha!
# Bad captcha!
# Bad captcha!
# 2272771
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '175')])
# 2272771
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '178')])
# Bad captcha!
# 2272771
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '185')])
# Bad captcha!
# Bad captcha!
# 2272771
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '205')])
# 2272771
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '198')])
# 2272771
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '171')])
# 2272771
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '194')])
# 2272771
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '186')])
# 2272771
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '188')])
# Bad captcha!
# Bad captcha!
# Bad captcha!
# 2272771
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '176')])
# 2272771
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '172')])
# 2272771
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '197')])
# 2272771
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '184')])
# Bad captcha!
# 2272771
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '204')])
# 2272771
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '206')])
# Bad captcha!
# 2272771
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '187')])
# 2272771
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '168')])
# Bad captcha!
# 2272771
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '195')])
# 2272771
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '182')])
# 2272771
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '177')])
# Bad captcha!
# Bad captcha!
# 2272771
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '5'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '180')])
# 2272771
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '1'), ('ricercaEsercizioFinanziario', 2017)])
# 2274869
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '3'), ('ricercaEsercizioFinanziario', 2017)])
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '3'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '156')])
# Bad captcha!
# 2274869
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '3'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '136')])
# 2274869
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '3'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '127')])
# Bad captcha!
# 2274869
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '3'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '132')])
# Bad captcha!
# 2274869
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '3'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '119')])
# 2274869
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '3'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '145')])
# Bad captcha!
# 2274869
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '3'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '161')])
# Bad captcha!
# Bad captcha!
# 2274869
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '3'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '122')])
# 2274869
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '3'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '154')])
# 2274869
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '3'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '117')])
# 2274869
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '3'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '138')])
# 2274870
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '3'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '118')])
# 2274870
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '3'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '128')])
# Bad captcha!
# 2274870
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '3'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '144')])
# Bad captcha!
# Bad captcha!
# 2274870
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '3'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '157')])
# Bad captcha!
# 2274870
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '3'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '151')])
# 2274870
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '3'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '120')])
# 2274870
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '3'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '149')])
# 2274870
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '3'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '121')])
# 2274870
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '3'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '147')])
# 2274870
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '3'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '159')])
# Bad captcha!
# Bad captcha!
# Bad captcha!
# 2274870
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '3'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '131')])
# 2274870
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '3'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '125')])
# 2274870
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '3'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '126')])
# 2274870
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '3'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '130')])
# 2274870
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '3'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '140')])
# 2274873
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '3'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '158')])
# Bad captcha!
# 2274873
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '3'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '139')])
# 2275368
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '3'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '133')])
# 2275368
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '3'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '160')])
# Bad captcha!
# 2275424
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '3'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '141')])
# 2275424
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '3'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '153')])
# 2275424
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '3'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '152')])
# 2275424
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '3'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '137')])
# Bad captcha!
# Bad captcha!
# 2275424
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '3'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '155')])
# 2275424
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '3'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '135')])
# Bad captcha!
# 2275424
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '3'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '123')])
# 2275424
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '3'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '148')])
# Bad captcha!
# 2275452
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '3'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '146')])
# Bad captcha!
# 2275452
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '3'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '134')])
# 2275452
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '3'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '124')])
# 2275452
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '3'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '150')])
# Bad captcha!
# 2275452
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '3'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '129')])
# 2275452
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '3'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '142')])
# 2275452
# Searching OrderedDict([('ricercaImportoPagamenti', '1'), ('ricercaMacroMisura', '3'), ('ricercaEsercizioFinanziario', 2017), ('ricercaMisura', '143')])
# Bad captcha!
# 2275452

# %%
len(df)
# Out:
# 2275452

# %%
df.head()
# Out:
#                                         recipient_id recipient_location  \
# 0  unaprol-consorzio-olivicolo-italiano-societa-c...         ROMA, ROMA
# 1  consorzio-nazionale-degli-olivicoltori-societa...         ROMA, ROMA
# 0              genagricola-spa-34132-trieste-trieste   TRIESTE, TRIESTE
# 1  consiglio-per-la-ricerca-in-agricoltura-e-l-an...         ROMA, ROMA
# 0              genagricola-spa-34132-trieste-trieste   TRIESTE, TRIESTE
#
#                                       recipient_name recipient_postcode  \
# 0  UNAPROL - CONSORZIO OLIVICOLO ITALIANO SOCIETA...              00187
# 1  CONSORZIO NAZIONALE DEGLI OLIVICOLTORI SOCIETA...              00187
# 0                                    GENAGRICOLA SPA              34132
# 1  CONSIGLIO PER LA RICERCA IN AGRICOLTURA E L'AN...              00198
# 0                                    GENAGRICOLA SPA              34132
#
#    total_amount country  year currency scheme
# 0   11607652.26      IT  2017      EUR
# 1    8045116.55      IT  2017      EUR
# 0    4686814.50      IT  2017      EUR
# 1    3537866.93      IT  2017      EUR
# 0    4686814.50      IT  2017      EUR
