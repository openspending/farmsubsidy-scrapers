# %%
import re
import glob
import codecs
import io

import requests

import pandas as pd
import numpy as np
from slugify import slugify

from tqdm import tqdm_notebook

from lxml import html

NUM_RE = re.compile(r'\d+')

YEAR = 2016

# %%
BASE_URL = 'https://eps.lad.gov.lv/payment_recipients'
QUERY = {
    'commit': 'Meklēt',
    'eps_payment[display_name]': '',
    'eps_payment[district]': '',
    'eps_payment[fund]': 'elf',
    'eps_payment[schema]': '',
    'eps_payment[sum_from]': '',
    'eps_payment[sum_to]': '',
    'eps_payment[tax_payer_number]': '',
    'eps_payment[year]': str(YEAR),
    'eps_payment[year_type]': 'F',
    'format': 'csv',
    'utf8': '✓',
}

# %%
response = requests.get('https://eps.lad.gov.lv/payment_recipients')
root = html.fromstring(response.content)
districts = root.xpath('.//select[@name="eps_payment[district]"]/option/@value')[1:]
districts
# Out:
# ['Latvija',
#  'Aglonas nov.',
#  'Aizkraukles nov.',
#  'Aizputes nov.',
#  'Aknīstes nov.',
#  'Alojas nov.',
#  'Alsungas nov.',
#  'Alūksnes nov.',
#  'Amatas nov.',
#  'Apes nov.',
#  'Auces nov.',
#  'Ādažu nov.',
#  'Babītes nov.',
#  'Baldones nov.',
#  'Baltinavas nov.',
#  'Balvu nov.',
#  'Bauskas nov.',
#  'Beverīnas nov.',
#  'Brocēnu nov.',
#  'Burtnieku nov.',
#  'Carnikavas nov.',
#  'Cesvaines nov.',
#  'Cēsu nov.',
#  'Ciblas nov.',
#  'Dagdas nov.',
#  'Daugavpils',
#  'Daugavpils nov.',
#  'Dobeles nov.',
#  'Dundagas nov.',
#  'Durbes nov.',
#  'Engures nov.',
#  'Ērgļu nov.',
#  'Garkalnes nov.',
#  'Grobiņas nov.',
#  'Gulbenes nov.',
#  'Iecavas nov.',
#  'Ikšķiles nov.',
#  'Ilūkstes nov.',
#  'Inčukalna nov.',
#  'Jaunjelgavas nov.',
#  'Jaunpiebalgas nov.',
#  'Jaunpils nov.',
#  'Jelgava',
#  'Jelgavas nov.',
#  'Jēkabpils',
#  'Jēkabpils nov.',
#  'Jūrmala',
#  'Kandavas nov.',
#  'Kārsavas nov.',
#  'Kocēnu nov.',
#  'Kokneses nov.',
#  'Krāslavas nov.',
#  'Krimuldas nov.',
#  'Krustpils nov.',
#  'Kuldīgas nov.',
#  'Ķeguma nov.',
#  'Ķekavas nov.',
#  'Lielvārdes nov.',
#  'Liepāja',
#  'Limbažu nov.',
#  'Līgatnes nov.',
#  'Līvānu nov.',
#  'Lubānas nov.',
#  'Ludzas nov.',
#  'Madonas nov.',
#  'Mazsalacas nov.',
#  'Mālpils nov.',
#  'Mārupes nov.',
#  'Mērsraga nov.',
#  'Naukšēnu nov.',
#  'Neretas nov.',
#  'Nīcas nov.',
#  'Ogres nov.',
#  'Olaines nov.',
#  'Ozolnieku nov.',
#  'Pārgaujas nov.',
#  'Pāvilostas nov.',
#  'Pļaviņu nov.',
#  'Preiļu nov.',
#  'Priekules nov.',
#  'Priekuļu nov.',
#  'Raunas nov.',
#  'Rēzekne',
#  'Rēzeknes nov.',
#  'Riebiņu nov.',
#  'Rīga',
#  'Rojas nov.',
#  'Ropažu nov.',
#  'Rucavas nov.',
#  'Rugāju nov.',
#  'Rundāles nov.',
#  'Rūjienas nov.',
#  'Salacgrīvas nov.',
#  'Salas nov.',
#  'Salaspils nov.',
#  'Saldus nov.',
#  'Saulkrastu nov.',
#  'Sējas nov.',
#  'Siguldas nov.',
#  'Skrīveru nov.',
#  'Skrundas nov.',
#  'Smiltenes nov.',
#  'Stopiņu nov.',
#  'Strenču nov.',
#  'Talsu nov.',
#  'Tērvetes nov.',
#  'Tukuma nov.',
#  'Vaiņodes nov.',
#  'Valkas nov.',
#  'Valmiera',
#  'Varakļānu nov.',
#  'Vārkavas nov.',
#  'Vecpiebalgas nov.',
#  'Vecumnieku nov.',
#  'Ventspils',
#  'Ventspils nov.',
#  'Viesītes nov.',
#  'Viļakas nov.',
#  'Viļānu nov.',
#  'Zilupes nov.']

# %%
for district in tqdm_notebook(districts):
    query = dict(QUERY)
    query['eps_payment[district]'] = district
    print('requesting', district)
    response = requests.get(BASE_URL, params=query)
    with open('lv_%s_%s.csv' % (YEAR, district), 'wb') as f:
        f.write(response.content)
# Out:
# HBox(children=(IntProgress(value=0, max=120), HTML(value='')))
# requesting Latvija
# requesting Aglonas nov.
# requesting Aizkraukles nov.
# requesting Aizputes nov.
# requesting Aknīstes nov.
# requesting Alojas nov.
# requesting Alsungas nov.
# requesting Alūksnes nov.
# requesting Amatas nov.
# requesting Apes nov.
# requesting Auces nov.
# requesting Ādažu nov.
# requesting Babītes nov.
# requesting Baldones nov.
# requesting Baltinavas nov.
# requesting Balvu nov.
# requesting Bauskas nov.
# requesting Beverīnas nov.
# requesting Brocēnu nov.
# requesting Burtnieku nov.
# requesting Carnikavas nov.
# requesting Cesvaines nov.
# requesting Cēsu nov.
# requesting Ciblas nov.
# requesting Dagdas nov.
# requesting Daugavpils
# requesting Daugavpils nov.
# requesting Dobeles nov.
# requesting Dundagas nov.
# requesting Durbes nov.
# requesting Engures nov.
# requesting Ērgļu nov.
# requesting Garkalnes nov.
# requesting Grobiņas nov.
# requesting Gulbenes nov.
# requesting Iecavas nov.
# requesting Ikšķiles nov.
# requesting Ilūkstes nov.
# requesting Inčukalna nov.
# requesting Jaunjelgavas nov.
# requesting Jaunpiebalgas nov.
# requesting Jaunpils nov.
# requesting Jelgava
# requesting Jelgavas nov.
# requesting Jēkabpils
# requesting Jēkabpils nov.
# requesting Jūrmala
# requesting Kandavas nov.
# requesting Kārsavas nov.
# requesting Kocēnu nov.
# requesting Kokneses nov.
# requesting Krāslavas nov.
# requesting Krimuldas nov.
# requesting Krustpils nov.
# requesting Kuldīgas nov.
# requesting Ķeguma nov.
# requesting Ķekavas nov.
# requesting Lielvārdes nov.
# requesting Liepāja
# requesting Limbažu nov.
# requesting Līgatnes nov.
# requesting Līvānu nov.
# requesting Lubānas nov.
# requesting Ludzas nov.
# requesting Madonas nov.
# requesting Mazsalacas nov.
# requesting Mālpils nov.
# requesting Mārupes nov.
# requesting Mērsraga nov.
# requesting Naukšēnu nov.
# requesting Neretas nov.
# requesting Nīcas nov.
# requesting Ogres nov.
# requesting Olaines nov.
# requesting Ozolnieku nov.
# requesting Pārgaujas nov.
# requesting Pāvilostas nov.
# requesting Pļaviņu nov.
# requesting Preiļu nov.
# requesting Priekules nov.
# requesting Priekuļu nov.
# requesting Raunas nov.
# requesting Rēzekne
# requesting Rēzeknes nov.
# requesting Riebiņu nov.
# requesting Rīga
# requesting Rojas nov.
# requesting Ropažu nov.
# requesting Rucavas nov.
# requesting Rugāju nov.
# requesting Rundāles nov.
# requesting Rūjienas nov.
# requesting Salacgrīvas nov.
# requesting Salas nov.
# requesting Salaspils nov.
# requesting Saldus nov.
# requesting Saulkrastu nov.
# requesting Sējas nov.
# requesting Siguldas nov.
# requesting Skrīveru nov.
# requesting Skrundas nov.
# requesting Smiltenes nov.
# requesting Stopiņu nov.
# requesting Strenču nov.
# requesting Talsu nov.
# requesting Tērvetes nov.
# requesting Tukuma nov.
# requesting Vaiņodes nov.
# requesting Valkas nov.
# requesting Valmiera
# requesting Varakļānu nov.
# requesting Vārkavas nov.
# requesting Vecpiebalgas nov.
# requesting Vecumnieku nov.
# requesting Ventspils
# requesting Ventspils nov.
# requesting Viesītes nov.
# requesting Viļakas nov.
# requesting Viļānu nov.
# requesting Zilupes nov.

# %%
# !head "lv_2016_Engures nov..csv"
# Out:
# ����
# "Maksjumu saFmji"
# "SaFmjs";"Atbalsta saFmja atraaans vieta";"SaFemto maksjumu periods";"ELGF un ELFLA, EUR"
# "Juris arbarts";"Engures nov.";"2015-2016";"3338.6"
# "";"";"Priekalaic+g pensionaans";"2496.32"
# "";"";"Priekalaic+g pensionaans";"842.28"
# eva";"Engures nov.";"2015-2016";"570.0"
# "";"";"Mazo lauksaimnieku atbalsta shmas maksjums";"500.0"
# "";"";"Kompenscijas maksjums par citiem apgabaliem, kuros ir ievrojami dabas ierobe~ojumi";"70.0"
# "Benita Lce";"Engures nov.";"2015-2016";"518.2"

# %%
COLUMNS = ['recipient_name',
           'recipient_location',
           'scheme',
           'amount'
]
FILENAMES = glob.glob('lv_%s_*.csv' % YEAR)
df = pd.concat([pd.read_csv(filename, encoding='utf-16', sep=';', skiprows=3, names=COLUMNS) for filename in FILENAMES])
df['recipient_name'] = df['recipient_name'].fillna(method='ffill')
df['recipient_location'] = df['recipient_location'].fillna(method='ffill')

# Remove totals
df = df[df['scheme'] != ('%s-%s' % (YEAR - 1, YEAR))]

df['recipient_postcode'] = None
df['recipient_address'] = None
df['recipient_country'] = 'LV'
df['currency'] = 'EUR'
df['year'] = YEAR
df.head()
# Out:
#      recipient_name recipient_location  \
# 1    Juris Čarbarts       Engures nov.
# 2    Juris Čarbarts       Engures nov.
# 4  Austra Tolkačeva       Engures nov.
# 5  Austra Tolkačeva       Engures nov.
# 7       Benita Lāce       Engures nov.
#
#                                               scheme   amount  \
# 1                        Priekšlaicīgā pensionēšanās  2496.32
# 2                        Priekšlaicīgā pensionēšanās   842.28
# 4       Mazo lauksaimnieku atbalsta shēmas maksājums   500.00
# 5  Kompensācijas maksājums par citiem apgabaliem,...    70.00
# 7       Mazo lauksaimnieku atbalsta shēmas maksājums   500.00
#
#   recipient_postcode recipient_address recipient_country currency  year
# 1               None              None                LV      EUR  2016
# 2               None              None                LV      EUR  2016
# 4               None              None                LV      EUR  2016
# 5               None              None                LV      EUR  2016
# 7               None              None                LV      EUR  2016

# %%
df['recipient_id'] = df['recipient_name'].apply(lambda x: x if pd.notnull(x) and NUM_RE.match(x) else np.nan)
df['recipient_id'] = df.apply(lambda x: 'LV-%s-%s' % (x['year'], x['recipient_id']) if pd.notnull(x['recipient_id']) else
                              'LV-%s-%s' % (slugify(
                                      x['recipient_location'] if pd.notnull(x['recipient_location']) else ''
                                  ), slugify(
                                      x['recipient_name'] if pd.notnull(x['recipient_name']) else ''
                                  )
                                ), 1)
df['recipient_name'] = df['recipient_name'].apply(lambda x: np.nan if pd.isnull(x) or NUM_RE.match(x) else x)

# %%
df.head()
# Out:
#      recipient_name recipient_location  \
# 1    Juris Čarbarts       Engures nov.
# 2    Juris Čarbarts       Engures nov.
# 4  Austra Tolkačeva       Engures nov.
# 5  Austra Tolkačeva       Engures nov.
# 7       Benita Lāce       Engures nov.
#
#                                               scheme   amount  \
# 1                        Priekšlaicīgā pensionēšanās  2496.32
# 2                        Priekšlaicīgā pensionēšanās   842.28
# 4       Mazo lauksaimnieku atbalsta shēmas maksājums   500.00
# 5  Kompensācijas maksājums par citiem apgabaliem,...    70.00
# 7       Mazo lauksaimnieku atbalsta shēmas maksājums   500.00
#
#   recipient_postcode recipient_address recipient_country currency  year  \
# 1               None              None                LV      EUR  2016
# 2               None              None                LV      EUR  2016
# 4               None              None                LV      EUR  2016
# 5               None              None                LV      EUR  2016
# 7               None              None                LV      EUR  2016
#
#                       recipient_id
# 1    LV-engures-nov-juris-carbarts
# 2    LV-engures-nov-juris-carbarts
# 4  LV-engures-nov-austra-tolkaceva
# 5  LV-engures-nov-austra-tolkaceva
# 7       LV-engures-nov-benita-lace

# %%
df.to_csv('lv_%s.csv.gz' % YEAR, index=False, compression='gzip', encoding='utf-8')
