# %%
import requests
from lxml import html

import pandas as pd

# %%
YEARS = [2017]

# %%
BASE_URL = 'http://saturn.etat.lu/mafea/result.do'
ENCODING = 'ISO-8859-1'

# %%
response = requests.get(BASE_URL)
root = html.fromstring(response.text)
COMMUNES = root.xpath('//select[@name="commune"]/option/@value')
AMOUNTS = root.xpath('//select[@name="value"]/option/@value')

# %%
def get_queries():
    for year in YEARS:
        for c in COMMUNES:
            yield (year, c,)


def download_year(year, commune):
    print('Running with', year, commune)
    session = requests.Session()

    for amount_range in AMOUNTS:
        response = session.post(BASE_URL, data={
            'year': str(year),
            'fond': '',
            'commune': commune,
            'name': '',
            'value': amount_range,
            'action': 'Rechercher'
        })
        response.encoding = ENCODING
        if 'Votre recherche ne retourne aucun résultat' in response.text:
            continue
        try:
            yield from extract_recipients(year, commune, amount_range, html.fromstring(response.text))
        except Exception as e:
            print('Exception at', year, commune, amount_range)
            raise e
    print('Done with', year, commune)

def extract_recipients(year, commune, amount_range, dom):
    for div in dom.xpath('.//div[@class="fieldsetWrapper"]'):
        results = div.xpath('.//table[@class="results"]//tr[@class="results"]')
        name_row = results[0]
        name_tds = name_row.xpath('./td/text()')
        if len(name_tds) == 3:
            name = '%s %s' % (name_tds[1], name_tds[0])
            location = name_tds[2]
            recipient_id = None
        else:
            name = None
            recipient_id = name_tds[0]
            location = name_tds[1]

        if recipient_id is None:
            recipient_id = 'LU-%s-%s' % (location, name)
        else:
            recipient_id = 'LU-%s-%s' % (year, recipient_id)

        value_rows = results[1:-1]
        for value_row in value_rows:
            val = value_row.xpath('./td/text()')
            scheme = val[1]
            amount = float(val[2].replace('€', ''))
            year = int(val[0])
            yield {
                'recipient_id': recipient_id,
                'recipient_name': name,
                'recipient_postcode': None,
                'recipient_location': location,
                'scheme': scheme,
                'amount': amount,
                'currency': 'EUR',
                'country': 'LU',
                'year': year,
            }

# %%
df = pd.DataFrame()
for year, commune in get_queries():
    df = pd.concat([df, pd.DataFrame(download_year(year, commune))])
    print(len(df))
    df.to_csv('lu_%s.csv.gz' % year, compression='gzip', index=False)
# Out:
# Running with 2017 (B) Attert
# Done with 2017 (B) Attert
# 1
# Running with 2017 (B) ARLON
# Done with 2017 (B) ARLON
# 6
# Running with 2017 (B) Bastogne
# Done with 2017 (B) Bastogne
# 8
# Running with 2017 (B) Bertogne
# Done with 2017 (B) Bertogne
# 10
# Running with 2017 (B) Burg-Reuland
# Done with 2017 (B) Burg-Reuland
# 15
# Running with 2017 (B) BASTOGNE
# Done with 2017 (B) BASTOGNE
# 17
# Running with 2017 (B) Messancy
# Done with 2017 (B) Messancy
# 22
# Running with 2017 (B) NAMUR
# Done with 2017 (B) NAMUR
# 24
# Running with 2017 (D) Bollendorf
# Done with 2017 (D) Bollendorf
# 26
# Running with 2017 (D) BITBURG-PRÜM
# Done with 2017 (D) BITBURG-PRÜM
# 26
# Running with 2017 (D) Schleiden
# Done with 2017 (D) Schleiden
# 29
# Running with 2017 (D) Trier-Land
# Done with 2017 (D) Trier-Land
# 35
# Done with 2017 Goesdorf
# 2563
# Running with 2017 Grevenmacher
# Done with 2017 Grevenmacher
# 2622
# Running with 2017 Grosbous
# Done with 2017 Grosbous
# 2694
# Running with 2017 GREVENMACHER
# Done with 2017 GREVENMACHER
# 2715
# Running with 2017 Habscht
# Done with 2017 Habscht
# 2796
# Running with 2017 Heffingen
# Done with 2017 Heffingen
# 2862
# Running with 2017 Helperknapp
# Done with 2017 Helperknapp
# 2992
# Running with 2017 Hesperange
# Done with 2017 Hesperange
# 3057
# Running with 2017 Hobscheid
# Done with 2017 Hobscheid
# 3057
# Running with 2017 Junglinster
# Done with 2017 Junglinster
# 3221
# Running with 2017 Käerjeng
# Done with 2017 Käerjeng
# 3221
# Running with 2017 Kayl
# Done with 2017 Kayl
# 3266
# Running with 2017 Kehlen
# Done with 2017 Kehlen
# 3431
# Running with 2017 Kiischpelt
# Done with 2017 Kiischpelt
# 3501
# Running with 2017 Koerich
# Done with 2017 Koerich
# 3563
# Running with 2017 Kopstal
# Done with 2017 Kopstal
# 3572
# Running with 2017 Lac de la Haute-Sûre
# Done with 2017 Lac de la Haute-Sûre
# 3572
# Running with 2017 Larochette
# Done with 2017 Larochette
# 3590
# Running with 2017 Lenningen
# Done with 2017 Lenningen
# 3620
# Running with 2017 Leudelange
# Done with 2017 Leudelange
# 3656
# Running with 2017 Lintgen
# Done with 2017 Lintgen
# 3686
# Running with 2017 Lorentzweiler
# Done with 2017 Lorentzweiler
# 3720
# Running with 2017 Luxembourg
# Done with 2017 Luxembourg
# 3766
# Running with 2017 LUXEMBOURG
# Done with 2017 LUXEMBOURG
# 3792
# Running with 2017 Mamer
# Done with 2017 Mamer
# 3870
# Running with 2017 Manternach
# Done with 2017 Manternach
# 3992
# Running with 2017 Mersch
# Done with 2017 Mersch
# 4144
# Running with 2017 Mertert
# Done with 2017 Mertert
# 4172
# Running with 2017 Mertzig
# Done with 2017 Mertzig
# 4209
# Running with 2017 Mompach
# Done with 2017 Mompach
# 4209
# Running with 2017 Mondercange
# Done with 2017 Mondercange
# 4279
# Running with 2017 Mondorf-les-Bains
# Done with 2017 Mondorf-les-Bains
# 4336
# Running with 2017 MERSCH
# Done with 2017 MERSCH
# 4350
# Running with 2017 Niederanven
# Done with 2017 Niederanven
# 4380
# Running with 2017 Nommern
# Done with 2017 Nommern
# 4510
# Running with 2017 Pétange
# Done with 2017 Pétange
# 4510
# Running with 2017 Parc Hosingen
# Done with 2017 Parc Hosingen
# 4745
# Running with 2017 Préizerdaul
# Done with 2017 Préizerdaul
# 4745
# Running with 2017 Putscheid
# Done with 2017 Putscheid
# 4816
# Running with 2017 Rambrouch
# Done with 2017 Rambrouch
# 5057
# Running with 2017 Reckange-sur-Mess
# Done with 2017 Reckange-sur-Mess
# 5123
# Running with 2017 Redange
# Done with 2017 Redange
# 5295
# Running with 2017 Reisdorf
# Done with 2017 Reisdorf
# 5358
# Running with 2017 Remich
# Done with 2017 Remich
# 5392
# Running with 2017 Roeser
# Done with 2017 Roeser
# 5474
# Running with 2017 Rosport
# Done with 2017 Rosport
# 5474
# Running with 2017 Rosport-Mompach
# Done with 2017 Rosport-Mompach
# 5748
# Running with 2017 REDANGE
# Done with 2017 REDANGE
# 5762
# Running with 2017 REMICH
# Done with 2017 REMICH
# 5780
# Running with 2017 Saeul
# Done with 2017 Saeul
# 5853
# Running with 2017 Sandweiler
# Done with 2017 Sandweiler
# 5858
# Running with 2017 Sanem
# Done with 2017 Sanem
# 5916
# Running with 2017 Schengen
# Done with 2017 Schengen
# 6184
# Running with 2017 Schieren
# Done with 2017 Schieren
# 6190
# Running with 2017 Schuttrange
# Done with 2017 Schuttrange
# 6253
# Running with 2017 Septfontaines
# Done with 2017 Septfontaines
# 6253
# Running with 2017 Stadtbredimus
# Done with 2017 Stadtbredimus
# 6307
# Running with 2017 Steinfort
# Done with 2017 Steinfort
# 6340
# Running with 2017 Steinsel
# Done with 2017 Steinsel
# 6380
# Running with 2017 Strassen
# Done with 2017 Strassen
# 6387
# Running with 2017 Tandel
# Done with 2017 Tandel
# 6613
# Running with 2017 Troisvierges
# Done with 2017 Troisvierges
# 6769
# Running with 2017 Tuntange
# Done with 2017 Tuntange
# 6769
# Running with 2017 Useldange
# Done with 2017 Useldange
# 6872
# Running with 2017 Vallée de l'Ernz
# Done with 2017 Vallée de l'Ernz
# 6872
# Running with 2017 Vianden
# Done with 2017 Vianden
# 6881
# Running with 2017 Vichten
# Done with 2017 Vichten
# 6967
# Running with 2017 VIANDEN
# Done with 2017 VIANDEN
# 6973
# Running with 2017 Wahl
# Done with 2017 Wahl
# 7062
# Running with 2017 Waldbillig
# Done with 2017 Waldbillig
# 7117
# Running with 2017 Waldbredimus
# Done with 2017 Waldbredimus
# 7165
# Running with 2017 Walferdange
# Done with 2017 Walferdange
# 7173
# Running with 2017 Weiler-la-Tour
# Done with 2017 Weiler-la-Tour
# 7228
# Running with 2017 Weiswampach
# Done with 2017 Weiswampach
# 7366
# Running with 2017 Wiltz
# Done with 2017 Wiltz
# 7489
# Running with 2017 Wincrange
# Done with 2017 Wincrange
# 8173
# Running with 2017 Winseler
# Done with 2017 Winseler
# 8254
# Running with 2017 Wormeldange
# Done with 2017 Wormeldange
# 8392
# Running with 2017 WILTZ
# Done with 2017 WILTZ
# 8413

# %%
df.head()
# Out:
#      amount country currency  \
# 0  21246.32      LU      EUR
# 0    128.29      LU      EUR
# 1     19.60      LU      EUR
# 2    126.36      LU      EUR
# 3    374.44      LU      EUR
#
#                                         recipient_id recipient_location  \
# 0  LU-(B) Attert-ASSISTANCE TECHNIQUE STEFFEN MAT...         (B) Attert
# 0                                      LU-2017-B0025          (B) ARLON
# 1                                      LU-2017-B0025          (B) ARLON
# 2                                      LU-2017-B0025          (B) ARLON
# 3                                      LU-2017-B0163          (B) ARLON
#
#                          recipient_name recipient_postcode   scheme  year
# 0  ASSISTANCE TECHNIQUE STEFFEN MATHIEU               None  IV/A.25  2017
# 0                                  None               None     II.1  2017
# 1                                  None               None     II.4  2017
# 2                                  None               None     II.6  2017
# 3                                  None               None     II.1  2017
